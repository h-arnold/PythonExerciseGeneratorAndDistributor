# %% [markdown]
# # Debug Logical Errors
#
# In this notebook, you'll fix logical errors in programs that use `print()`, simple arithmetic, variables, and `input()`.
#
# ## What you'll practise
# - Finding wrong operators
# - Spotting wrong variables being used
# - Fixing calculation errors
# - Correcting string operations
# - Converting input from strings to numbers
# - Fixing order of operations
#
# ## How to work
# 1. Each exercise shows what the **correct output** should be
# 2. Read the buggy code in the `exercise` cell
# 3. Write a brief explanation of what was wrong
# 4. Fix the errors so the code produces the correct output
# 5. Run `pytest -q` to check your work

# %% [markdown]
# ## Exercise 1 — Calculate total cost
#
# **Expected output:**
# ```
# 50
# ```

# %%
price = 10
quantity = 5
total = price + quantity
print(total)

# %% [markdown]
# ### What actually happened
# Describe what incorrect output you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 2 — Display a name
#
# **Expected output:**
# ```
# Alice
# ```

# %%
name = "Alice"
username = "Bob"
print(username)

# %% [markdown]
# ### What actually happened
# Describe what incorrect output you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 3 — Calculate area
#
# **Expected output:**
# ```
# 24
# ```

# %%
width = 6
height = 4
area = width / height
print(area)

# %% [markdown]
# ### What actually happened
# Describe what incorrect output you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 4 — Create a message
#
# **Expected output:**
# ```
# Hello World
# ```

# %%
word1 = "Hello"
word2 = "World"
message = word1 + word2
print(message)

# %% [markdown]
# ### What actually happened
# Describe what incorrect output you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 5 — Build a full name
#
# **Expected output:**
# ```
# Enter first name: [Input: Alice]
# Enter last name: [Input: Smith]
# Alice Smith
# ```

# %%
first_name = input("Enter first name: ")
last_name = input("Enter last name: ")
full_name = first_name + last_name
print(full_name)

# %% [markdown]
# ### What actually happened
# Describe what incorrect output you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 6 — Calculate change
#
# **Expected output:**
# ```
# 5
# ```

# %%
paid = 20
cost = 15
change = cost - paid
print(paid)

# %% [markdown]
# ### What actually happened
# Describe what incorrect output you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 7 — Calculate average
#
# **Expected output:**
# ```
# 25.0
# ```

# %%
score1 = 20
score2 = 30
total = score1 * score2
average = total + 2
print(average)

# %% [markdown]
# ### What actually happened
# Describe what incorrect output you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 8 — Build a sentence
#
# **Expected output:**
# ```
# I love learning Python
# ```

# %%
word1 = "I"
word2 = "love"
word3 = "learning"
word4 = "Python"
sentence = word1 + word2 + word3 + word4
print(sentence)

# %% [markdown]
# ### What actually happened
# Describe what incorrect output you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 9 — Calculate perimeter
#
# **Expected output:**
# ```
# 30
# ```

# %%
length = 10
width = 5
perimeter = length + length + width
print(length)

# %% [markdown]
# ### What actually happened
# Describe what incorrect output you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 10 — Display user information
#
# **Expected output:**
# ```
# Enter your age: [Input: 15]
# Enter your city: [Input: London]
# You are 15 years old and live in London
# ```

# %%
age = input("Enter your age: ")
city = input("Enter your city: ")
message = "You are " + age + " years old and live in" + city
print(message)

# %% [markdown]
# ### What actually happened
# Describe what incorrect output you got and why. Fix the code above.

# %%
# Optional self-check (not graded)
# You can run small experiments here.

# %%
# Check your answers (not graded)
from tests.student_checker import check_notebook

check_notebook("ex005_sequence_debug_logic")
# Out:
# +-------------+---------------+----------+-----------------------------------------+
# | Exercise    | Check         | Status   | Error                                   |
# +=============+===============+==========+=========================================+
# | Exercise 1  | Static output | 🔴 NO    | expected '50'.                          |
# +-------------+---------------+----------+-----------------------------------------+
# |             | Explanation   | 🔴 NO    | explanation needs more detail.          |
# +-------------+---------------+----------+-----------------------------------------+
# | Exercise 2  | Static output | 🔴 NO    | expected 'Alice'.                       |
# +-------------+---------------+----------+-----------------------------------------+
# |             | Explanation   | 🔴 NO    | explanation needs more detail.          |
# +-------------+---------------+----------+-----------------------------------------+
# ...
