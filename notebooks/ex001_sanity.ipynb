# %% [markdown]
# # Sanity Exercise
#
# ## Goal
# Write your solution in the **student** cell, then run the tests.
#
# ## How to work
# - Edit the code in the cell tagged `student`
# - Run `pytest -q`

# %%
# STUDENT CELL (graded)
# The tests will execute the code in this cell.

def example() -> str:
    """Return a non-empty string."""
    return "TODO"

# %%
# Optional self-check (not graded)
print(example())

# %%
from tests.student_checker import check_notebook

check_notebook('ex001_sanity')
