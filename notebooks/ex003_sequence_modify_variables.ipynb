# %% [markdown]
# # Sequence Modify Variables
#
# In this notebook you practise assigning strings to variables, storing typed text with `input()`, and joining those values together so the final `print()` output matches the expected message.
#
# ## What you'll practise
# - Assigning new string literals to variables so `print()` reflects the latest value.
# - Using `input()` to capture typed text and store it for later use.
# - Concatenating variables with `+` to build a full sentence.
#
# ## How to work
# 1. Read the task description.
# 2. Edit the working code so the output matches the expected message.
# 3. Run `pytest -q` once every cell produces the correct text.
#
# Each exercise cell is tagged `exercise1` through `exercise10`.

# %% [markdown]
# ## Exercise 1 — Change the greeting value
#
# **Working code:**
# ```python
# greeting = "Hello from Python!"
# print(greeting)
# ```
#
# **Task:** Set `greeting = "Hi there!"` so the output looks exactly like this:
# ```
# Hi there!
# ```

# %%
# Exercise 1 — YOUR CODE
# Modify the greeting assignment below
greeting = "Hello from Python!"
print(greeting)

# %% [markdown]
# ## Exercise 2 — Update the subject
#
# **Working code:**
# ```python
# subject = "math"
# print("I enjoy " + subject + " lessons.")
# ```
#
# **Task:** Change `subject` to `"coding"` so the program prints `I enjoy coding lessons.`

# %%
# Exercise 2 — YOUR CODE
# Change the subject variable to a different string
subject = "math"
print("I enjoy " + subject + " lessons.")

# %% [markdown]
# ## Exercise 3 — Favourite food
#
# **Working code:**
# ```python
# food = "pasta"
# print("My favourite food is " + food)
# ```
#
# **Task:** Assign `food = "sushi"` so the output becomes `My favourite food is sushi`.

# %%
# Exercise 3 — YOUR CODE
# Use a new favourite food below
food = "pasta"
print("My favourite food is " + food)

# %% [markdown]
# ## Exercise 4 — Read a fruit with input
#
# **Working code:**
# ```python
# print("What is your favourite fruit?")
# fruit = input()
# print("My favourite fruit is " + fruit)
# ```
#
# **Task:** Update the first line to `Type the name of your favourite fruit:` and the final message to `I like ` + `fruit`.
#
# **Expected output:**
# ```
# Type the name of your favourite fruit: [Input: mango]
# Type one word to describe it: [Input: tropical]
# I like mango because it is tropical
# ```

# %%
# Exercise 4 — YOUR CODE
# Update the prompt to the new wording and the final message
print("What is your favourite fruit?")
fruit = input()
print("My favourite fruit is " + fruit)

# %% [markdown]
# ## Exercise 5 — Ask about a town
#
# **Working code:**
# ```python
# print("Tell me your favourite place:")
# place = input()
# print("I love visiting " + place)
# ```
#
# **Task:** Change the prompt to `Which town do you like the most?` and the final message to `I would visit ` + `place`.
#
# **Expected output:**
# ```
# Which town do you like the most? [Input: Cardiff]
# Which country is it in? [Input: Wales]
# I would visit Cardiff in Wales
# ```

# %%
# Exercise 5 — YOUR CODE
# Update the prompt and final message
print("Tell me your favourite place:")
place = input()
print("I love visiting " + place)

# %% [markdown]
# ## Exercise 6 — Greet someone by name
#
# **Working code:**
# ```python
# print("Enter your name:")
# name = input()
# print("Hello there, " + name)
# ```
#
# **Task:** Update the prompt to `Please enter your name:` and the final line to `Welcome, ` + `name` + `!`.
#
# **Expected output:**
# ```
# Please enter your first name: [Input: Alex]
# Please enter your last name: [Input: Morgan]
# Welcome, Alex Morgan!
# ```

# %%
# Exercise 6 — YOUR CODE
# Update the prompt and the final message
print("Enter your name:")
name = input()
print("Hello there, " + name)

# %% [markdown]
# ## Exercise 7 — Build a short sentence
#
# **Working code:**
# ```python
# first_word = "Learning"
# second_word = "Python"
# print(first_word + " " + second_word)
# ```
#
# **Task:** Replace the words so the output is `Variables matter`.
#
# **Expected output:**
# ```
# Variables matter
# ```

# %%
# Exercise 7 — YOUR CODE
# Replace the literal strings with input() calls for `first_word` and `second_word`.
first_word = "Learning"
second_word = "Python"
# e.g., first_word = input("Enter first word:")
print(first_word + " " + second_word)

# %% [markdown]
# ## Exercise 8 — Keep experimenting
#
# **Working code:**
# ```python
# part1 = "Keep"
# part2 = "coding"
# print(part1 + " " + part2)
# ```
#
# **Task:** Update the second word so the final line reads `Keep experimenting`.
#
# **Expected output:**
# ```
# Keep experimenting
# ```

# %%
# Exercise 8 — YOUR CODE
# Use two input() calls to collect an action and an object, then print them.
part1 = "Keep"
part2 = "coding"
# e.g., part1 = input("Enter an action:")
print(part1 + " " + part2)

# %% [markdown]
# ## Exercise 9 — Add an audience
#
# **Working code:**
# ```python
# greeting = "Good"
# time_of_day = "morning"
# audience = "students"
# print(greeting + " " + time_of_day + " " + audience)
# ```
#
# **Task:** Change the strings so the output becomes `Good evening everyone!`.
#
# **Expected output:**
# ```
# Good evening everyone!
# ```

# %%
# Exercise 9 — YOUR CODE
# Use input() to collect `greeting`, `time_of_day`, and `audience`, then print them together.
greeting = "Good"
time_of_day = "morning"
audience = "students"
# e.g., greeting = input("Enter a greeting:")
print(greeting + " " + time_of_day + " " + audience)

# %% [markdown]
# ## Exercise 10 — Combine three parts
#
# **Working code:**
# ```python
# part_one = "Python"
# part_two = "strings"
# part_three = "matter"
# print(part_one + " " + part_two + " " + part_three)
# ```
#
# **Task:** Assign new values so the print statement outputs `Variables and strings make a message!`.
#
# **Expected output:**
# ```
# Variables and strings make a message!
# ```

# %%
# Exercise 10 — YOUR CODE
# Collect three parts using input() and then print them joined into a sentence.
part_one = "Python"
part_two = "strings"
part_three = "matter"
# e.g., part_one = input("Enter part one:")
print(part_one + " " + part_two + " " + part_three)

# %%
# Optional self-check (not graded)
# Try changing the words and prompt text below as extra practice.
language = "Python"
topic = "variables"
print("I love " + language + " and " + topic + "!")

# %%
# Check your answers (not graded)
from tests.student_checker import check_notebook

check_notebook("ex003_sequence_modify_variables")
