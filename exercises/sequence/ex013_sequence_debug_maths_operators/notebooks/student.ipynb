# %% [markdown]
# # Debug Maths Operators
#
# In this notebook you will find and fix bugs in programs that use maths operators.
#
# > 💡 **Stuck?** Use the [Arithmetic Cheatsheet](../../additional-resources/ARITHMETIC_CHEATSHEET.md) to remind yourself what each operator does.
#
# ## What you will practise
# - Floor division `//` to get whole groups.
# - Modulus `%` to find the remainder.
# - `round(value, places)` to control decimal places.
# - Using variables, `input()`, casting with `int()` and `float()`, and f-strings.
#
# ## How to work
# 1. Read the task and **expected output** carefully.
# 2. Run the buggy code — observe the error or wrong output.
# 3. Fix the bug(s) so the output matches exactly.
# 4. Write a short explanation of what was wrong.
# 5. Run `uv run pytest -q` to check your work.

# %% [markdown]
# ## Exercise 1 — Full groups only
#
# **Expected output:**
# ```
# Full groups: 6
# ```
#
# **Task:** Fix the operator bug AND convert the `print` line to use an f-string instead of `+` concatenation.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

students = 25
group_size = 4
full_groups = students / group_size
print("Full groups: " + str(group_size))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 7
#       5 group_size = 4
#       6 full_groups = students / group_size
# ----> 7 print("Full groups: " + str(group_size))
#
# File <stringsource>:69, in cfunc.to_py.__Pyx_CFunc_b0409f__29_pydevd_sys_monitoring_cython_object__lParen__etc_to_py_4code_4line.wrap()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1481, in _pydevd_sys_monitoring_cython._line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1602, in _pydevd_sys_monitoring_cython._internal_line_event()
#
# File _pydevd_sys_monitoring\\_pydevd_sys_monitoring_cython.pyx:1961, in _pydevd_sys_monitoring_cython._do_wait_suspend()
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/.venv/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2188, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2185             from_this_thread.append(frame_custom_thread_id)
#    2187     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2188         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2190 frames_list = None
#    2192 if keep_suspended:
#    2193     # This means that we should pause again after a set next statement.
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/.venv/lib/python3.12/site-packages/debugpy/_vendored/pydevd/pydevd.py:2257, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2254                 queue.put(internal_cmd)
#    2255                 wait_timeout = TIMEOUT_FAST
# -> 2257         notify_event.wait(wait_timeout)
#    2258         notify_event.clear()
#    2260 finally:
#
# File /usr/local/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /usr/local/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ### 🐞 Debug this code

# %%
students = 25
group_size = 4
full_groups = students / group_size
print("Full groups: " + str(full_groups))

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 2 — Find the leftover
#
# **Expected output:**
# ```
# Leftover: 1
# ```
#
# **Task:** Fix the operator bug AND convert the `print` line to use an f-string instead of `+` concatenation.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

sweets = 25
per_bag = 4
leftover = sweets - per_bag
print("Leftover: " + str(leftover))

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ### 🐞 Debug this code

# %%
sweets = 25
per_bag = 4
leftover = sweets - per_bag
print("Leftover: " + str(leftover))

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 3 — Round an average
#
# **Expected output:**
# ```
# Average: 6.7
# ```

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

total = 20
count = 3
average = total / count
print(f"Average: {average}")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ### 🐞 Debug this code

# %%
total = 20
count = 3
average = total / count
print(f"Average: {average}")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 4 — Teams from input
#
# **Expected output:**
# ```
# How many players? [⌨️: 23]
# Full teams: 4
# ```

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

players = input("How many players? ")
teams = players // 5
print(f"Full teams: {teams}")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ### 🐞 Debug this code

# %%
players = input("How many players? ")
teams = players // 5
print(f"Full teams: {teams}")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 5 — Round money to 2 decimal places
#
# **Expected output:**
# ```
# Total: £3.77
# ```

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

price = 1.257
qty = 3
total = price * qty
total = round(total, 2)
print(f"Total: £{price}")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ### 🐞 Debug this code

# %%
price = 1.257
qty = 3
total = price * qty
total = round(total, 2)
print(f"Total: £{price}")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 6 — Split minutes
#
# **Expected output:**
# ```
# 200 minutes is 3 hours and 20 minutes
# ```

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

minutes = 200
hours = minutes / 60
minutes_left = minutes - 60
print(f"{minutes} minutes is {hours} hours and {minutes_left} minutes")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ### 🐞 Debug this code

# %%
minutes = 200
hours = minutes / 60
minutes_left = minutes - 60
print(f"{minutes} minutes is {hours} hours and {minutes_left} minutes")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 7 — Pence to pounds
#
# **Expected output:**
# ```
# Enter pence: [⌨️: 389]
# 389p is £3 and 89p
# ```

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

pence = input("Enter pence: ")
pounds = pence // 100
leftover = pence - 100
print(f"{pence}p is £{pounds} and {leftover}p")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ### 🐞 Debug this code

# %%
pence = input("Enter pence: ")
pounds = pence // 100
leftover = pence - 100
print(f"{pence}p is £{pounds} and {leftover}p")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 8 — Area of a square
#
# **Expected output:**
# ```
# Area of square: 5.5
# ```

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

length = 2.345
area = length * length
rounded = round(area, 3)
print(f"Area of square: {area}")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ### 🐞 Debug this code

# %%
length = 2.345
area = length * length
rounded = round(area, 3)
print(f"Area of square: {area}")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 9 — Apples into bags
#
# **Expected output:**
# ```
# Full bags: 9, Left over: 2
# ```

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

apples = 47
per_bag = 5
bags = apples / per_bag
left = apples % per_bag
print("Full bags: {bags}, Left over: {left}")

# %% [markdown]
# ### What actually happened
# Describe what error or wrong output you got, and what you changed to fix it.

# %% [markdown]
# ### 🐞 Debug this code

# %%
apples = 47
per_bag = 5
bags = apples / per_bag
left = apples % per_bag
print("Full bags: {bags}, Left over: {left}")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 10 — Mixed challenge
#
# **Expected output:**
# ```
# How many items? [⌨️: 29]
# How many per box? [⌨️: 6]
# Total cost? £ [⌨️: 10.99]
# Full boxes: 4
# Leftover items: 5
# Cost per box: £2.75
# ```

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

items = input("How many items? ")
box_size = input("How many per box? ")
total_cost = float(input("Total cost? £"))

boxes = items / box_size
leftover = items - box_size
cost_per_box = total_cost / boxes
cost_per_box = round(cost_per_box, 2)

print(f"Full boxes: {boxes}")
print(f"Leftover items: {leftover}")
print(f"Cost per box: £{cost_per_box}")

# %% [markdown]
# ### What actually happened
# Describe what errors or wrong output you got, and what you changed to fix them.

# %% [markdown]
# ### 🐞 Debug this code

# %%
items = input("How many items? ")
box_size = input("How many per box? ")
total_cost = float(input("Total cost? £"))

boxes = items / box_size
leftover = items - box_size
cost_per_box = total_cost / boxes
cost_per_box = round(cost_per_box, 2)

print(f"Full boxes: {boxes}")
print(f"Leftover items: {leftover}")
print(f"Cost per box: £{cost_per_box}")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %%
# Self-check scratch cell (not graded)
# You can run small experiments here.

# %% [markdown]
# ## Check your work
# Run the code below to find out if you have completed your tasks correctly

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

run_notebook_checks('ex013_sequence_debug_maths_operators')
