# %% [markdown]
# # Debug Syntax Errors
#
# In this notebook, you'll fix common syntax errors that arise when using `print()`, simple arithmetic, variables, and `input()`.
#
# ## What you'll practise
# - Fixing missing closing parentheses
# - Adding missing quotes around strings
# - Correcting variable names
# - Fixing string concatenation with `+`
# - Fixing misused operators
# - Fixing `input()` usage
#
# ## How to work
# 1. Each exercise shows what the **correct output** should be
# 2. Read the buggy code in the `exercise` cell
# 3. Write a brief explanation of what was wrong
# 4. Fix the errors so the code runs and produces the correct output
# 5. Run `pytest -q` to check your work

# %% [markdown]
# ## Exercise 1 — Print a message
#
# **Expected output:**
# ```
# Hello World!
# ```

# %%
print("Hello World!"

# %% [markdown]
# ### What actually happened
# Describe what error you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 2 — Print a greeting
#
# **Expected output:**
# ```
# I like Python
# ```

# %%
print(I like Python)

# %% [markdown]
# ### What actually happened
# Describe what error you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 3 — Join two words
#
# **Expected output:**
# ```
# Learning Python
# ```

# %%
print("Learning" "Python")

# %% [markdown]
# ### What actually happened
# Describe what error you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 4 — Calculate a result
#
# **Expected output:**
# ```
# 50
# ```

# %%
print(5 + 10)

# %% [markdown]
# ### What actually happened
# Describe what error you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 5 — Print a greeting with a variable
#
# **Expected output:**
# ```
# Hello Alice
# ```

# %%
name = "Alice"
print("Hello " + nam)

# %% [markdown]
# ### What actually happened
# Describe what error you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 6 — Store and print a message
#
# **Expected output:**
# ```
# Welcome to school
# ```

# %%
greeting = Welcome to school"
print(greeting

# %% [markdown]
# ### What actually happened
# Describe what errors you found and why. Fix the code above.

# %% [markdown]
# ## Exercise 7 — String concatenation
#
# **Expected output:**
# ```
# How many apples? 5
# You have 5 apples
# ```

# %%
apples = input("How many apples? ")
print("You have " apples " apples")

# %% [markdown]
# ### What actually happened
# Describe what error you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 8 — Read user input
#
# **Expected output:**
# ```
# Enter your name: Alice
# Hello Alice
# ```

# %%
name = input
print("Hello " + name)

# %% [markdown]
# ### What actually happened
# Describe what error you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 9 — Print a phrase
#
# **Expected output:**
# ```
# It's amazing
# ```

# %%
print('It's amazing')

# %% [markdown]
# ### What actually happened
# Describe what error you got and why. Fix the code above.

# %% [markdown]
# ## Exercise 10 — Ask and respond
#
# **Expected output:**
# ```
# What is your favourite colour? Blue
# My favourite colour is Blue
# ```

# %%
colour = input("What is your favourite colour?
print("My favourite colour is " colour)

# %% [markdown]
# ### What actually happened
# Describe briefly what happened when you ran the code (include any error messages or incorrect output).

# %%
# Optional self-check (not graded)
# You can run small experiments here.

# %%
from tests.student_checker import check_notebook

check_notebook('ex004_sequence_debug_syntax')
# Out:
# +-------------+------------+----------+------------------------------------------+
# | Exercise    | Check      | Status   | Error                                    |
# +=============+============+==========+==========================================+
# | Exercise 1  | exercise1  | 🔴 NO    | Failed to compile code tagged            |
# |             |            |          | 'exercise1' in                           |
# |             |            |          | ex004_sequence_debug_syntax.ipynb: '('   |
# |             |            |          | was never closed                         |
# |             |            |          | (ex004_sequence_debug_syntax.ipynb, line |
# |             |            |          | 1)                                       |
# +-------------+------------+----------+------------------------------------------+
# | Exercise 2  | exercise2  | 🔴 NO    | Failed to compile code tagged            |
# |             |            |          | 'exercise2' in                           |
# |             |            |          | ex004_sequence_debug_syntax.ipynb:       |
# |             |            |          | invalid syntax. Perhaps you forgot a     |
# |             |            |          | comma?                                   |
# |             |            |          | (ex004_sequence_debug_syntax.ipynb, line |
# |             |            |          | 1)                                       |
# +-------------+------------+----------+------------------------------------------+
# | Exercise 3  | exercise3  | 🟢 OK    |                                          |
# +-------------+------------+----------+------------------------------------------+
# | Exercise 4  | exercise4  | 🟢 OK    |                                          |
# +-------------+------------+----------+------------------------------------------+
# | Exercise 5  | exercise5  | 🔴 NO    | Execution failed for code tagged         |
# |             |            |          | 'exercise5' in                           |
# |             |            |          | ex004_sequence_debug_syntax.ipynb: name  |
# |             |            |          | 'nam' is not defined                     |
# +-------------+------------+----------+------------------------------------------+
# | Exercise 6  | exercise6  | 🔴 NO    | Failed to compile code tagged            |
# |             |            |          | 'exercise6' in                           |
# |             |            |          | ex004_sequence_debug_syntax.ipynb:       |
# |             |            |          | unterminated string literal (detected at |
# |             |            |          | line 1)                                  |
# |             |            |          | (ex004_sequence_debug_syntax.ipynb, line |
# |             |            |          | 1)                                       |
# +-------------+------------+----------+------------------------------------------+
# | Exercise 7  | exercise7  | 🔴 NO    | Failed to compile code tagged            |
# |             |            |          | 'exercise7' in                           |
# |             |            |          | ex004_sequence_debug_syntax.ipynb:       |
# |             |            |          | invalid syntax. Perhaps you forgot a     |
# |             |            |          | comma?                                   |
# |             |            |          | (ex004_sequence_debug_syntax.ipynb, line |
# |             |            |          | 3)                                       |
# +-------------+------------+----------+------------------------------------------+
# | Exercise 8  | exercise8  | 🔴 NO    | Execution failed for code tagged         |
# |             |            |          | 'exercise8' in                           |
# |             |            |          | ex004_sequence_debug_syntax.ipynb: can   |
# |             |            |          | only concatenate str (not "method") to   |
# |             |            |          | str                                      |
# +-------------+------------+----------+------------------------------------------+
# | Exercise 9  | exercise9  | 🔴 NO    | Failed to compile code tagged            |
# |             |            |          | 'exercise9' in                           |
# |             |            |          | ex004_sequence_debug_syntax.ipynb:       |
# |             |            |          | unterminated string literal (detected at |
# |             |            |          | line 1)                                  |
# |             |            |          | (ex004_sequence_debug_syntax.ipynb, line |
# |             |            |          | 1)                                       |
# +-------------+------------+----------+------------------------------------------+
# | Exercise 10 | exercise10 | 🔴 NO    | Failed to compile code tagged            |
# |             |            |          | 'exercise10' in                          |
# |             |            |          | ex004_sequence_debug_syntax.ipynb:       |
# |             |            |          | unterminated string literal (detected at |
# |             |            |          | line 1)                                  |
# |             |            |          | (ex004_sequence_debug_syntax.ipynb, line |
# |             |            |          | 1)                                       |
# +-------------+------------+----------+------------------------------------------+
#
# Fix the failing cells above, then re-run this cell.
