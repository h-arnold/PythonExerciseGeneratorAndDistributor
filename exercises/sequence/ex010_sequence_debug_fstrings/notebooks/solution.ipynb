# %% [markdown]
# # Sequence Debug F-Strings
#
#
#
# This notebook shows corrected versions of the f-string debugging tasks.
#
#
#
# Each part keeps the same structure as the student notebook so the exercise tests can run against either variant.

# %% [markdown]
# ## Exercise 1 - Welcome message
#
#
#
# This program should print a welcome message using the variable value.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Welcome, Sam!
#
# ```

# %%
name = "Sam"

print(f"Welcome, {name}!")

# %% [markdown]
# ### What actually happened
#
#
#
# The string was missing the `f` before the opening quote, so `{name}` was printed as plain text instead of showing the value in the variable. I fixed it by changing the print line into an f-string.

# %% [markdown]
# ## Exercise 2 - Pet sentence
#
#
#
# This program should print the pet stored in the variable.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# My pet is a rabbit!
#
# ```

# %%
pet = "rabbit"

print(f"My pet is a {pet}!")

# %% [markdown]
# ### What actually happened
#
#
#
# The f-string used `animal`, but that variable did not exist. That caused a name error. I fixed it by using the correct variable name, `pet`, inside the braces.

# %% [markdown]
# ## Exercise 3 - After-school activity
#
#
#
# This program should use both variables in the final sentence.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Mia enjoys drawing after school.
#
# ```

# %%
person = "Mia"

hobby = "drawing"

print(f"{person} enjoys {hobby} after school.")

# %% [markdown]
# ### What actually happened
#
#
#
# The word `hobby` was written as plain text inside the f-string, so the output showed the word itself instead of the value stored in the variable. I fixed it by putting `hobby` inside curly braces.

# %% [markdown]
# ## Exercise 4 - Favourite lesson
#
#
#
# This program should print the lesson stored in the variable, including the full stop.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Our best lesson is computing.
#
# ```

# %%
lesson = "computing"

print(f"Our best lesson is {lesson}.")

# %% [markdown]
# ### What actually happened
#
#
#
# The variable name was outside the braces, so the sentence printed the word `lesson` instead of the value `computing`. I fixed the output by placing the variable inside curly braces in the f-string.

# %% [markdown]
# ## Exercise 5 - Snack choice
#
#
#
# This program should ask for a snack and print the answer in the final sentence.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Type your favourite snack: [Input: popcorn]
#
# You chose popcorn for break time.
#
# ```

# %%
snack = input("Type your favourite snack: ")

print(f"You chose {snack} for break time.")

# %% [markdown]
# ### What actually happened
#
#
#
# The final print line was an ordinary string, so `{snack}` stayed as text instead of showing the user's input. I fixed it by changing the print line to an f-string.

# %% [markdown]
# ## Exercise 6 - Greeting from a town
#
#
#
# This program should use both inputs in the final greeting.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Enter your first name: [Input: Aisha]
#
# Enter your town: [Input: Leeds]
#
# Hello Aisha from Leeds.
#
# ```

# %%
name = input("Enter your first name: ")

town = input("Enter your town: ")

print(f"Hello {name} from {town}.")

# %% [markdown]
# ### What actually happened
#
#
#
# The final message used the word `town` as plain text, so the output did not include the town the user typed. I fixed the bug by putting the `town` variable inside curly braces in the f-string.

# %% [markdown]
# ## Exercise 7 - Score update
#
#
#
# This program should print the score stored in the variable.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# You scored 4 goals today.
#
# ```

# %%
goals = 4

print(f"You scored {goals} goals today.")

# %% [markdown]
# ### What actually happened
#
#
#
# The number was correct, but the sentence said `goal` instead of `goals`, so the output did not match the expected text exactly. I fixed the wording in the f-string.

# %% [markdown]
# ## Exercise 8 - Ticket total
#
#
#
# This program should add the two ticket values and print the total in the final sentence.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Tickets sold altogether: 7
#
# ```

# %%
adult_tickets = 4

child_tickets = 3

total_tickets = adult_tickets + child_tickets

print(f"Tickets sold altogether: {total_tickets}")

# %% [markdown]
# ### What actually happened
#
#
#
# There were two bugs. The code subtracted the ticket counts instead of adding them, and the final print line was not an f-string, so `{total_tickets}` would not show the value. I fixed the calculation and changed the print line to an f-string.

# %% [markdown]
# ## Exercise 9 - Reading total
#
#
#
# This program should add the two values and print the total pages read.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Pages read in two days: 20
#
# ```

# %%
pages_today = 12

pages_tomorrow = 8

total_pages = pages_today + pages_tomorrow

print(f"Pages read in two days: {total_pages}")

# %% [markdown]
# ### What actually happened
#
#
#
# There were two bugs in this cell. The code subtracted the page totals instead of adding them, and the print line was a plain string, so `{total_pages}` would not show the value. I fixed the calculation and changed the final line to an f-string.

# %% [markdown]
# ## Exercise 10 - Pencil cost
#
#
#
# This program should work out the total cost and print the number of pencils.
#
#
#
# **Expected output:**
#
#
#
# ```text
#
# Total cost for 6 pencils: £3.0
#
# ```

# %%
price = 0.5

amount = 6

total_cost = price * amount

print(f"Total cost for {amount} pencils: £{total_cost}")

# %% [markdown]
# ### What actually happened
#
#
#
# This cell had two bugs. The total cost should be found by multiplying the price by the amount, not adding them, and the final f-string needed `{amount}` so the number of pencils appeared in the message. I corrected the calculation and the f-string text.

# %%
# Self-check scratch cell (not graded)
# You can run small experiments here.

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

# Pass the canonical exercise_key here; do not pass a notebook path.
run_notebook_checks('ex010_sequence_debug_fstrings')
