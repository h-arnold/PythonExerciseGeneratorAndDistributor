# %% [markdown]
# # Data Types Debug Casting
#
# ## Goal
# Fix the bugs in each exercise by correcting data type and casting mistakes.
#
# ## How to work
# - Run each buggy code cell to see what goes wrong
# - Fix only the exercise cell, then re-run it
# - Describe what happened in the explanation cell

# %% [markdown]
# # Exercise 1 - Joining text and numbers
# You are given a short message that mixes text and a number.
#
# ### Expected output
# ```
# You have 3 pens
# ```

# %%
# BUGGY CODE (students edit this tagged cell)
# Fix the code below and run the cell.

count = 3
message = "You have " + count + " pens"
print(message)

# %% [markdown]
# ### What actually happened
# After running the buggy code, describe the fault and how you fixed it.

# %% [markdown]
# # Exercise 2 - Showing a price
# The program should print a price with pounds.
#
# ### Expected output
# ```
# Total price: £7.5
# ```

# %%
# BUGGY CODE (students edit this tagged cell)
# Fix the code below and run the cell.

price_pounds = 7.5
label = "Total price: £"
print(label + int(price_pounds))

# %% [markdown]
# ### What actually happened
# After running the buggy code, describe the fault and how you fixed it.

# %% [markdown]
# # Exercise 3 - Next year’s age
# The program should ask for an age and add one.
#
# ### Expected output
# ```
# Enter your age: [Input: 14]
# Next year you will be 15
# ```

# %%
# BUGGY CODE (students edit this tagged cell)
# Fix the code below and run the cell.

age_text = input("Enter your age: ")
next_age = age_text + 1
print("Next year you will be " + str(next_age))

# %% [markdown]
# ### What actually happened
# After running the buggy code, describe the fault and how you fixed it.

# %% [markdown]
# # Exercise 4 - Average per day
# The program should calculate the average distance per day.
#
# ### Expected output
# ```
# Average per day: 3.5 km
# ```

# %%
# BUGGY CODE (students edit this tagged cell)
# Fix the code below and run the cell.

total_distance = 7
days = 2
average = total_distance // days
print("Average per day: " + str(average) + " km")

# %% [markdown]
# ### What actually happened
# After running the buggy code, describe the fault and how you fixed it.

# %% [markdown]
# # Exercise 5 - Repeat a word
# The program should repeat a word a number of times.
#
# ### Expected output
# ```
# Word to repeat: [Input: hi]
# How many times? [Input: 3]
# hihihi
# ```

# %%
# BUGGY CODE (students edit this tagged cell)
# Fix the code below and run the cell.

word = input("Word to repeat: ")
repeat_text = input("How many times? ")
print(word * repeat_text)

# %% [markdown]
# ### What actually happened
# After running the buggy code, describe the fault and how you fixed it.

# %% [markdown]
# # Exercise 6 - Celsius to Fahrenheit
# The program should convert a temperature from Celsius to Fahrenheit.
#
# ### Expected output
# ```
# Enter temperature in Celsius: [Input: 20]
# Temperature in Fahrenheit: 68.0
# ```

# %%
# BUGGY CODE (students edit this tagged cell)
# Fix the code below and run the cell.

temp_celsius = input("Enter temperature in Celsius: ")
fahrenheit = temp_celsius * 9 / 5 + "32"
print("Temperature in Fahrenheit: " + str(fahrenheit))

# %% [markdown]
# ### What actually happened
# After running the buggy code, describe the fault and how you fixed it.

# %% [markdown]
# # Exercise 7 - Total cost
# The program should calculate the total cost from price and quantity.
#
# ### Expected output
# ```
# Enter price per item (£): [Input: 1.5]
# Enter quantity: [Input: 4]
# Total cost: £6.0
# ```

# %%
# BUGGY CODE (students edit this tagged cell)
# Fix the code below and run the cell.

price_text = input("Enter price per item (£): ")
quantity_text = input("Enter quantity: ")
total_cost = price_text * quantity_text
print("Total cost: £" + total_cost)

# %% [markdown]
# ### What actually happened
# After running the buggy code, describe the fault and how you fixed it.

# %% [markdown]
# # Exercise 8 - Average score
# The program should calculate the average of three scores.
#
# ### Expected output
# ```
# Enter score 1: [Input: 12]
# Enter score 2: [Input: 15]
# Enter score 3: [Input: 9]
# Average score: 12.0
# ```

# %%
# BUGGY CODE (students edit this tagged cell)
# Fix the code below and run the cell.

score1 = input("Enter score 1: ")
score2 = input("Enter score 2: ")
score3 = input("Enter score 3: ")
total_score = score1 + score2 + score3
average_score = total_score // 3
print("Average score: " + str(average_score))

# %% [markdown]
# ### What actually happened
# After running the buggy code, describe the fault and how you fixed it.

# %% [markdown]
# # Exercise 9 - Total pence
# The program should convert pounds and pence into total pence.
#
# ### Expected output
# ```
# Pounds: [Input: 3]
# Pence: [Input: 45]
# Total pence: 345
# ```

# %%
# BUGGY CODE (students edit this tagged cell)
# Fix the code below and run the cell.

pounds_text = input("Pounds: ")
pence_text = input("Pence: ")
total_pence = pounds_text * 100 + pence_text
print("Total pence: " + total_pence)

# %% [markdown]
# ### What actually happened
# After running the buggy code, describe the fault and how you fixed it.

# %% [markdown]
# # Exercise 10 - Split the bill
# The program should split a bill with a 10% tip.
#
# ### Expected output
# ```
# Total bill (£): [Input: 20]
# Number of people: [Input: 4]
# Each person pays: £5.5
# ```

# %%
# BUGGY CODE (students edit this tagged cell)
# Fix the code below and run the cell.

total_bill_text = input("Total bill (£): ")
people_text = input("Number of people: ")
tip_rate = 0.1
total_with_tip = total_bill_text + total_bill_text * tip_rate
per_person = total_with_tip // people_text
print("Each person pays: £" + str(per_person))

# %% [markdown]
# ### What actually happened
# After running the buggy code, describe the fault and how you fixed it.

# %%
# Optional self-check (not graded)
# You can run small experiments here.

# %%
from exercise_runtime_support.student_checker import run_notebook_checks

run_notebook_checks('ex007_sequence_debug_casting')
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[1], line 3
#       1 from exercise_runtime_support.student_checker import run_notebook_checks
# ----> 3 run_notebook_checks('ex007_sequence_debug_casting')
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/exercise_runtime_support/student_checker/notebook_runtime.py:45, in run_notebook_checks(exercise_key)
#      42     print(f"No exercise tags found in {resolved_path}.")
#      43     return
# ---> 45 results = _run_notebook_checks(resolved_path, tags)
#      46 _print_notebook_check_results(results)
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/exercise_runtime_support/student_checker/notebook_runtime.py:111, in _run_notebook_checks(path, tags)
#     109 for tag in tags:
#     110     try:
# --> 111         _run_tagged_cell(str(path), tag)
#     112         results.append(NotebookTagCheckResult(tag=tag, passed=True, message=""))
#     113     except NotebookGradingError as exc:
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/exercise_runtime_support/student_checker/notebook_runtime.py:119, in _run_tagged_cell(notebook_path, tag)
#     118 def _run_tagged_cell(notebook_path: str, tag: str) -> None:
# --> 119     input_calls = _count_input_calls(notebook_path, tag=tag)
#     120     if input_calls == 0:
#     121         run_cell_and_capture_output(notebook_path, tag=tag)
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/exercise_runtime_support/student_checker/notebook_runtime.py:155, in _count_input_calls(notebook_path, tag)
#     153 def _count_input_calls(notebook_path: str, *, tag: str) -> int:
#     154     """Count direct `input()` calls in a tagged code cell."""
# --> 155     code = extract_tagged_code(notebook_path, tag=tag)
#     156     try:
#     157         tree = ast.parse(code)
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/exercise_runtime_support/notebook_grader.py:113, in extract_tagged_code(notebook_path, tag, variant)
#      97 def extract_tagged_code(
#      98     notebook_path: str | Path,
#      99     *,
#     100     tag: str = "student",
#     101     variant: Variant | None = None,
#     102 ) -> str:
#     103     """Return the concatenated source of all code cells tagged with `tag`.
#     104
#     105     The notebook is expected to be a standard `.ipynb` JSON file where each cell has:
#    (...)    110     We keep this pure-stdlib (no nbformat/nbclient dependency) to reduce classroom friction.
#     111     """
# --> 113     nb = _read_notebook(notebook_path, variant=variant)
#     114     cells = nb.get("cells")
#     115     if not isinstance(cells, list):
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/exercise_runtime_support/notebook_grader.py:46, in _read_notebook(notebook_path, variant)
#      41 def _read_notebook(
#      42     notebook_path: str | Path,
#      43     *,
#      44     variant: Variant | None = None,
#      45 ) -> dict[str, Any]:
# ---> 46     path = resolve_notebook_path(notebook_path, variant=variant)
#      47     if not path.exists():
#      48         raise NotebookGradingError(f"Notebook not found: {path}")
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/exercise_runtime_support/notebook_grader.py:38, in resolve_notebook_path(notebook_path, variant)
#      32 def resolve_notebook_path(
#      33     notebook_path: str | Path,
#      34     *,
#      35     variant: Variant | None = None,
#      36 ) -> Path:
#      37     """Resolve an exercise_key string or explicit notebook Path."""
# ---> 38     return resolve_framework_notebook_path(notebook_path, variant=variant)
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/exercise_runtime_support/exercise_framework/paths.py:161, in resolve_notebook_path(notebook_path, variant)
#     159 if isinstance(notebook_path, str):
#     160     if _is_path_like_string(notebook_path):
# --> 161         _raise_path_like_string_error(notebook_path)
#     162     return resolve_exercise_notebook_path(notebook_path, variant=selected_variant)
#     164 if _has_local_metadata_package(repo_root) and _is_source_legacy_notebook_path(
#     165     notebook_path,
#     166     repo_root,
#     167 ):
#
# File /workspaces/PythonExerciseGeneratorAndDistributor/exercise_runtime_support/exercise_framework/paths.py:36, in _raise_path_like_string_error(notebook_path)
#      35 def _raise_path_like_string_error(notebook_path: str) -> None:
# ---> 36     raise LookupError(
#      37         "resolver input must be an exercise_key, not a path-like string: "
#      38         f"{notebook_path!r}. Path-like inputs are not supported."
#      39     )
#
# LookupError: resolver input must be an exercise_key, not a path-like string: '/workspaces/PythonExerciseGeneratorAndDistributor/exercises/sequence/ex007_sequence_debug_casting/notebooks/student.ipynb'. Path-like inputs are not supported.
