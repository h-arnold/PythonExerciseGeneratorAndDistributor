# %% [markdown]
# # Selection — Debug Errors (Solution)
#
# ## Goal
# This is the instructor solution notebook. Each exercise shows the corrected code and explains the bug.

# %% [markdown]
# ## Exercise 1 — Even or odd?
#
# **Expected output** (when the user types `7`):
# ```
# Odd number!
# ```
#
# The program should check if a number is even or odd using the modulus operator (`%`).

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
if number % 2 == 0
    print("Even number!")
else:
    print("Odd number!")

# %% [markdown]
# ### What was wrong
# The `if` statement was missing the colon (`:`) at the end of the condition line.

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
if number % 2 == 0:  # Bug: missing colon at end of line
    print("Even number!")
else:
    print("Odd number!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 2 — Circle area
#
# **Expected output** (when the user types `6`):
# ```
# Area exceeds 100!
# ```
#
# The program calculates the area of a circle (`π × r²`) and checks if it exceeds 100.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

radius_input = input("Enter the radius: ")
radius = float(radius_input)
area = 3.14159 * radius ** 2
if area = 100:
    print("Area exceeds 100!")
else:
    print("Area is 100 or less")

# %% [markdown]
# ### What was wrong
# Used `=` (assignment) instead of `>` (comparison). The original code had `area = 100` which is assignment, not comparison. Changed to `area > 100` to check if area exceeds 100.

# %% [markdown]
# ### 🐞 Debug this code

# %%
radius_input = input("Enter the radius: ")
radius = float(radius_input)
area = 3.14159 * radius ** 2
if area > 100:  # Bug: was using = instead of ==
    print("Area exceeds 100!")
else:
    print("Area is 100 or less")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 3 — Divisible by 3?
#
# **Expected output** (when the user types `9`):
# ```
# Divisible by 3!
# ```
#
# The program checks if a number is exactly divisible by 3 (remainder is 0).

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
remainder = number % 3
if remainder == 0:
print("Divisible by 3!")
else:
    print(f"Remainder is {remainder}")

# %% [markdown]
# ### What was wrong
# The `print` statement inside the `if` block was not indented. Added 4 spaces before `print`.

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
remainder = number % 3
if remainder == 0:
    print("Divisible by 3!")  # Bug: missing indentation
else:
    print(f"Remainder is {remainder}")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 4 — Square check
#
# **Expected output** (when the user types `35`):
# ```
# Square is greater than 1000!
# ```
#
# The program squares a number and checks if the result is greater than 1000.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
squared = number ** 2
if squared < 1000:
    print("Square is greater than 1000!")
else:
    print("Square is 1000 or less")

# %% [markdown]
# ### What was wrong
# Used `<` instead of `>`. The comparison was backwards — saying "greater than 1000" but checking if less than 1000. Changed `<` to `>`.

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
squared = number ** 2
if squared > 1000:  # Bug: used < instead of >
    print("Square is greater than 1000!")
else:
    print("Square is 1000 or less")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 5 — Favourite colour
#
# **Expected output** (when the user types `blue`):
# ```
# Nice choice!
# ```
#
# The program checks if the user's favourite colour is `"blue"`.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

colour = input("What is your favourite colour? ")
if colour == blue:
    print("Nice choice!")
else:
    print("That's a nice colour too!")

# %% [markdown]
# ### What was wrong
# The string `blue` was not quoted. Without quotes, Python tries to find a variable called `blue` (which doesn't exist). Added quotes: `"blue"`.

# %% [markdown]
# ### 🐞 Debug this code

# %%
colour = input("What is your favourite colour? ")
if colour == "blue":  # Bug: blue was not quoted (treated as variable name)
    print("Nice choice!")
else:
    print("That's a nice colour too!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 6 — PIN check
#
# **Expected output** (when the user types `5678`):
# ```
# Wrong PIN!
# ```
#
# The program checks if the entered PIN is **not** `1234`.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

pin_input = input("Enter your PIN: ")
pin = int(pin_input)
if pin ! 1234:
    print("Wrong PIN!")
else:
    print("Access granted")

# %% [markdown]
# ### What was wrong
# Used `!` instead of `!=`. In Python, `!=` is the "not equal" operator.

# %% [markdown]
# ### 🐞 Debug this code

# %%
pin_input = input("Enter your PIN: ")
pin = int(pin_input)
if pin != 1234:  # Bug: ! instead of != (invalid syntax)
    print("Wrong PIN!")
else:
    print("Access granted")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 7 — Two errors
#
# **Expected output** (when the user types `8`):
# ```
# Correct answer!
# ```
#
# This program has **two** errors.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

answer_input = input("What is 3 + 5? ")
if answer = 8
    print("Correct answer!")
else:
    print("Wrong answer!")

# %% [markdown]
# ### What was wrong
# Two errors: (1) `=` instead of `==`, (2) missing colon at end of the `if` line.

# %% [markdown]
# ### 🐞 Debug this code

# %%
answer_input = input("What is 3 + 5? ")
answer = int(answer_input)
if answer == 8:  # Bug 1: = instead of ==, Bug 2: missing colon
    print("Correct answer!")
else:
    print("Wrong answer!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 8 — Three errors
#
# **Expected output** (when the user types `140`):
# ```
# You can ride!
# ```
#
# This program has **three** errors.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

height_input = input("Enter your height in cm: ")
height = int(height_input)
if height = 130
print("You can ride!")
else:
    print("Too short!")

# %% [markdown]
# ### What was wrong
# Three errors: (1) `=` instead of `>=` (should check if height is 130 or more), (2) missing colon, (3) `print` not indented inside the `if` block.

# %% [markdown]
# ### 🐞 Debug this code

# %%
height_input = input("Enter your height in cm: ")
height = int(height_input)
if height >= 130:  # Bug 1: = instead of ==, Bug 2: missing colon
    print("You can ride!")  # Bug 3: missing indentation
else:
    print("Too short!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 9 — Four errors
#
# **Expected output** (when the user types `60`):
# ```
# You passed!
# ```
#
# This program has **four** errors.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

score_input = input("Enter your score: ")
score = int(score_input)
if score = 50
print("You passed!")
else:
    print("You passed!")

# %% [markdown]
# ### What was wrong
# Four errors: (1) `=` instead of `>=` (should check if score is 50 or more), (2) missing colon, (3) `print` not indented, (4) the `else` branch printed `"You passed!"` instead of `"You failed!"`.

# %% [markdown]
# ### 🐞 Debug this code

# %%
score_input = input("Enter your score: ")
score = int(score_input)
if score >= 50:  # Bug 1: = instead of >=, Bug 2: missing colon
    print("You passed!")  # Bug 3: missing indentation
else:
    print("You failed!")  # Bug 4: else printed "passed" instead of "failed"

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 10 — Five errors
#
# **Expected output** (when the user types `Bob`):
# ```
# Hello Bob!
# ```
#
# This is the hardest syntax exercise — it has **five** errors.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

name = input("Enter your name: ")
if name = Bob
print("Hello Bob!")
else:
    print("I don't know you")

# %% [markdown]
# ### What was wrong
# Five errors: (1) `=` instead of `==`, (2) missing colon, (3) `Bob` not quoted, (4) `print` not indented, (5) `else` block had wrong indentation.

# %% [markdown]
# ### 🐞 Debug this code

# %%
name = input("Enter your name: ")
if name == "Bob":  # Bug 1: = instead of ==, Bug 2: missing colon, Bug 3: missing quotes
    print("Hello Bob!")  # Bug 4: missing indentation
else:
    print("I don't know you")  # Bug 5: wrong indentation (extra spaces on else)

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ---
#
# # Logic Errors
#
# The exercises above tested **syntax errors** — code that crashes immediately. The exercises below test **logic errors** — code that runs but produces the **wrong output**.

# %% [markdown]
# ## Exercise 11 — Award certificate
#
# **Expected output** (when the user types `90`):
# ```
# Distinction
# ```
#
# The program checks if a score is 90 or above to award a Distinction.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

score_input = input("Enter your score: ")
score = int(score_input)
if score > 90:
    print("Distinction")
else:
    print("Pass")

# %% [markdown]
# ### What was wrong
# Used `>` instead of `>=`. A score of exactly 90 was not being counted as Distinction. Changed to `>=` to include 90.

# %% [markdown]
# ### 🐞 Debug this code

# %%
score_input = input("Enter your score: ")
score = int(score_input)
if score >= 90:  # Bug: used > instead of >= (off-by-one)
    print("Distinction")
else:
    print("Pass")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 12 — Age group
#
# **Expected output** (when the user types `12`):
# ```
# Child
# ```
#
# The program checks if someone is 12 or younger to label them as a Child.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

age_input = input("Enter your age: ")
age = int(age_input)
if age < 12:
    print("Child")
else:
    print("Teenager")

# %% [markdown]
# ### What was wrong
# Used `<` instead of `<=`. An age of exactly 12 was not being labelled as Child. Changed to `<=` to include 12.

# %% [markdown]
# ### 🐞 Debug this code

# %%
age_input = input("Enter your age: ")
age = int(age_input)
if age <= 12:  # Bug: used < instead of <= (off-by-one)
    print("Child")
else:
    print("Teenager")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 13 — Positive or negative?
#
# **Expected output** (when the user types `5`):
# ```
# Positive
# ```
#
# The program should say Positive for numbers greater than 0 and Negative otherwise.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
if number < 0:
    print("Positive")
else:
    print("Negative")

# %% [markdown]
# ### What was wrong
# Used `< 0` instead of `> 0`. The comparison was reversed — positive numbers were being called Negative. Changed direction.

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
if number > 0:  # Bug: used < instead of > (reversed direction)
    print("Positive")
else:
    print("Negative")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 14 — Password check
#
# **Expected output** (when the user types `python`):
# ```
# Correct password!
# ```
#
# The program should accept the password `"python"` and reject everything else.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

password = input("Enter the password: ")
if password == "python":
    print("Wrong password!")
else:
    print("Correct password!")

# %% [markdown]
# ### What was wrong
# The messages were swapped. When password matches, it printed "Wrong password" and vice versa. Swapped the messages.

# %% [markdown]
# ### 🐞 Debug this code

# %%
password = input("Enter the password: ")
if password == "python":
    print("Correct password!")  # Bug: messages were swapped
else:
    print("Wrong password!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 15 — Temperature warning
#
# **Expected output** (when the user types `35`):
# ```
# It's hot!
# ```
#
# The program checks the temperature. Above 30 should be hot, 30 or below should be cold.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

temp_input = input("Enter the temperature: ")
temperature = int(temp_input)
if temperature > 30:
    print("It's cold!")
else:
    print("It's hot!")

# %% [markdown]
# ### What was wrong
# The messages were swapped. High temperatures were printing "It's cold!" and low temperatures were printing "It's hot!". Swapped the messages.

# %% [markdown]
# ### 🐞 Debug this code

# %%
temp_input = input("Enter the temperature: ")
temperature = int(temp_input)
if temperature > 30:
    print("It's hot!")  # Bug: messages were swapped
else:
    print("It's cold!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 16 — Even or odd?
#
# **Expected output** (when the user types `7`):
# ```
# Odd number
# ```
#
# The program should say Even or Odd for any number.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
if number % 2 == 0:
    print("Even number")

# %% [markdown]
# ### What was wrong
# The `else` clause was missing. Odd numbers produced no output at all. Added `else: print("Odd number")`.

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
if number % 2 == 0:
    print("Even number")
else:
    print("Odd number")  # Bug: missing else clause

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 17 — Valid age
#
# **Expected output** (when the user types `-5`):
# ```
# Invalid age
# ```
#
# The program checks if an age is valid (0 to 150).

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

age_input = input("Enter your age: ")
age = int(age_input)
if age <= 150:
    print("Valid age")
else:
    print("Invalid age")

# %% [markdown]
# ### What was wrong
# Only checked `age <= 150` (upper bound) but missed `age >= 0` (lower bound). Negative ages were accepted as valid. Added the lower bound check.
#
# **Note:** This exercise uses `and` which we haven't taught yet. For this exercise, we're showing the full fix. An alternative without `and` would use nested `if` statements.

# %% [markdown]
# ### 🐞 Debug this code

# %%
age_input = input("Enter your age: ")
age = int(age_input)
if age >= 0 and age <= 150:  # Bug: missing lower bound check (only checked upper)
    print("Valid age")
else:
    print("Invalid age")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 18 — Grade calculator
#
# **Expected output** (when the user types `95`):
# ```
# Excellent score
# ```
#
# The program should check a score and say Excellent for 90 or above.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

score_input = input("Enter your score: ")
score = int(score_input)
age = 0
if age >= 90:
    print("Excellent score")
else:
    print("Good try")

# %% [markdown]
# ### What was wrong
# The code had an extra variable `age = 0` and was checking `age >= 90` instead of `score >= 90`. Removed the extra variable and changed the condition to check `score`.

# %% [markdown]
# ### 🐞 Debug this code

# %%
score_input = input("Enter your score: ")
score = int(score_input)
if score >= 90:  # Bug: was checking 'age' instead of 'score'
    print("Excellent score")
else:
    print("Good try")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ---
#
# # Mixed Errors
#
# The final two exercises combine **syntax errors** AND **logic errors**.

# %% [markdown]
# ## Exercise 19 — Number checker (2 errors)
#
# **Expected output** (when the user types `10`):
# ```
# Number is 10 or greater
# ```
#
# This program has **one syntax error** and **one logic error**.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

number_input = input("Enter a number: ")
number = int(number_input)
if number > 10
    print("Number is greater than 10")
else:
    print("Number is 10 or less")

# %% [markdown]
# ### What was wrong
# Two errors: (1) Missing colon on `if` line (syntax), (2) Used `>` instead of `>=` (logic) — so typing 10 gave the wrong message.

# %% [markdown]
# ### 🐞 Debug this code

# %%
number_input = input("Enter a number: ")
number = int(number_input)
if number >= 10:  # Bug 1: missing colon (syntax), Bug 2: should be >= not > (logic)
    print("Number is 10 or greater")
else:
    print("Number is less than 10")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %% [markdown]
# ## Exercise 20 — Score checker (3 errors)
#
# **Expected output** (when the user types `75`):
# ```
# You passed!
# ```
#
# This is the final boss! It has **two syntax errors** and **one logic error**.

# %%
# READ-ONLY — observe the buggy code below
# This cell is not tested. Run it to see what happens.

score_input = input("Enter your score: ")
score = int(score_input)
if score >= 50
print("You failed!")
else:
    print("You passed!")

# %% [markdown]
# ### What was wrong
# Three errors: (1) missing colon on `if` line (syntax), (2) `print` not indented inside the `if` block (syntax), (3) the messages were swapped — the `if` block printed `"You failed!"` and the `else` block printed `"You passed!"` (logic).

# %% [markdown]
# ### 🐞 Debug this code

# %%
score_input = input("Enter your score: ")
score = int(score_input)
if score >= 50:  # Bug 1: missing colon (syntax)
    print("You passed!")  # Bug 2: missing indentation, Bug 3: messages were swapped (logic)
else:
    print("You failed!")

# %% [markdown]
# 🏁️ **Finished?** ✅ [Check your work](#check-your-work).

# %%
# Self-check scratch cell (not graded)
# You can run small experiments here.

# %% [markdown]
# ## Check your work
# Run the code below to find out if you have completed your tasks correctly

# %%
import os

os.environ["PYTUTOR_ACTIVE_VARIANT"] = "solution"

from exercise_runtime_support.student_checker import run_notebook_checks

run_notebook_checks('ex002_selection_debug_if_then_else')
